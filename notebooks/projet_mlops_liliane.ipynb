# %%
# Projet MLOps - Prédiction du risque de défaut bancaire
# Objectif : Construire un modèle de machine learning capable de prédire la probabilité de défaut de paiement

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Notebook initialisé")
# Out:
# Notebook initialisé

# %%
# Création d'un petit dataset simulé
data = pd.DataFrame({
    "age": np.random.randint(18, 70, 100),
    "income": np.random.randint(20000, 90000, 100),
    "loan_amount": np.random.randint(1000, 20000, 100),
    "default": np.random.randint(0, 2, 100)
})

data.head()
# Out:
#    age  income  loan_amount  default
# 0   68   66885        10337        1
# 1   51   48495         8353        1
# 2   47   59102        11352        1
# 3   19   58826        18300        1
# 4   30   39721         7087        1

# %%
data.describe()
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 data.describe()
# ----> 2 sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
#       3 plt.show()
#
# NameError: name 'sns' is not defined
